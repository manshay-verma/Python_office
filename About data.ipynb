# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dt = pd.read_csv("system_object_202505121221.csv")

# %%
dt.head(10)
# Out:
#                            name     revision  db_id  object_id  \
# 0                          test            A      1    33.1000
# 1  SO.Test.10.07.2024.SubAssy.3          A.0     81    27.8100
# 2                      Node1234            A    637    29.6370
# 3            Program - July 2nd            A     11    54.1100
# 4          automation_item_ocoe          A.0   6193    27.6193
# 5             Item July 2nd - 2            A      5    27.5000
# 6          automation_item_smse          A.0   5698    27.5698
# 7                    Task6781-2  newRevision    639    35.6390
# 8  SO.Test.12.07.2024.SubAssy.2    dummyTest    896    35.8960
# 9                   test file 1            A    588    25.5880
#
#                            group_id         description  major_id  is_final  \
# 0  d2e97e7ddfdf438eb46655088b490983                 NaN   33.1000     False
# 1  de59011f75b94240852408f4e87dee12                   z   27.8000     False
# ...

# %%
dt.isnull().sum()
# Out:
# name                                0
# revision                            0
# db_id                               0
# object_id                           0
# group_id                            0
# description                      5795
# major_id                            0
# is_final                            0
# is_iteration                        0
# is_revision                         0
# is_latest_iteration                 0
# is_latest_revision                  0
# is_best_so_far                      0
# created_at                          0
# updated_at                          0
# finalized_at                     6808
# is_reserved                         0
# has_parent                          0
# has_child                           0
# to_relation_count                   0
# from_relation_count                 0
# has_files                           0
# file_count                          0
# is_deleted                          0
# deleted_at                       6648
# ...

# %%
dt.dtypes
# Out:
# name                              object
# revision                          object
# db_id                              int64
# object_id                        float64
# group_id                          object
# description                       object
# major_id                         float64
# is_final                            bool
# is_iteration                        bool
# is_revision                         bool
# is_latest_iteration                 bool
# is_latest_revision                  bool
# is_best_so_far                      bool
# created_at                        object
# updated_at                        object
# finalized_at                      object
# is_reserved                         bool
# has_parent                          bool
# has_child                           bool
# to_relation_count                  int64
# from_relation_count                int64
# has_files                           bool
# file_count                         int64
# ...

# %%
df = dt.loc[:, ['created_at', 'updated_at']]

# %%
# Out:
#                          created_at                     updated_at
# 0     2024-07-01 17:42:27.727 +0530  2024-07-01 17:42:27.804 +0530
# 1     2024-07-12 14:42:26.083 +0530  2024-08-13 14:54:05.820 +0530
# 2     2024-08-07 19:32:35.735 +0530  2024-08-07 19:32:36.099 +0530
# 3     2024-07-02 19:03:18.611 +0530  2024-07-02 19:03:18.735 +0530
# 4     2025-02-19 22:52:30.261 +0530  2025-02-19 22:52:53.331 +0530
# ...                             ...                            ...
# 7018  2024-12-02 19:53:40.244 +0530  2025-05-12 10:14:17.527 +0530
# 7019  2025-04-11 15:28:01.165 +0530  2025-04-11 15:28:01.184 +0530
# 7020  2025-04-11 15:24:34.233 +0530  2025-04-11 15:25:51.606 +0530
# 7021  2025-05-12 11:32:21.778 +0530  2025-05-12 11:32:22.217 +0530
# 7022  2025-05-12 11:32:21.891 +0530  2025-05-12 11:32:21.917 +0530
#
# [7023 rows x 2 columns]

# %%
dt["is_final"].value_counts()
# Out:
# is_final
# False    6789
# True      234
# Name: count, dtype: int64

# %%
dt["group_id"].value_counts()
# Out:
# group_id
# bd827a983ddb4a0697a4261b959dd3c0    38
# 9c0cb6d2d6db412c8356d1ac4cbc52f9    28
# 3574b817e0b04c5ca943f9a8145f0ddb    24
# 31a2b3c49ae34162b952f7dd1ce87575    23
# 9575cd4d7341466aaca1417e2f91a004    18
#                                     ..
# e5a9490581bb4cc99d3d1a47f11346c0     1
# 06ec7eaff6d548a39cf7ce2a3164bc54     1
# c4ae400eb8a74494b82cc6114345e9d3     1
# d8e8819668574f428c7b7cc41cca5b2f     1
# c996126e7446488092d9306b8978382f     1
# Name: count, Length: 4198, dtype: int64

# %%
dt.shape
# Out:
# (7023, 44)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7023 entries, 0 to 7022
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  7023 non-null   object
#  1   updated_at  7023 non-null   object
# dtypes: object(2)
# memory usage: 109.9+ KB
