# %%
# Import all the tool we needs
# Regular EDA Exploratory data analysis and plotting libreary

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# we want our plot to appeat inside the notebook
# %matplotlib inline

# %%
df = pd.read_csv("system_object_202505121221.csv")

# %%
df.shape
# Out:
# (7023, 44)

# %%
df.tail()
# Out:
#                                                    name revision  db_id  \
# 7018  item_nov_18_item_item+item_nov_18_item_nov_18_...      B.0   3124
# 7019                            11_april_item00002 - 01      A.0   7995
# 7020                                 11_april_item00001      A.0   7987
# 7021                      test Docx document 12th may 1        A   8540
# 7022                      test Docx document 12th may 1      A.0   8541
#
#       object_id                          group_id  description  major_id  \
# 7018    27.3124  31a2b3c49ae34162b952f7dd1ce87575  item_nov_18   27.3123
# 7019    27.7995  c23ae2fe7ac84039a912c362ab728aa9          NaN   27.7994
# 7020    27.7987  ef0ffe86d20e44c78eae27246c1e74b8          NaN   27.7986
# 7021    25.8540  c4c751fe1ef5460e9db0b740073c1a9d          NaN   25.8540
# 7022    25.8541  c4c751fe1ef5460e9db0b740073c1a9d          NaN   25.8540
#
#       is_final  is_iteration  is_revision  ...  reserved_by_id  state_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7023 entries, 0 to 7022
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           7023 non-null   object
#  1   revision                       7023 non-null   object
#  2   db_id                          7023 non-null   int64
#  3   object_id                      7023 non-null   float64
#  4   group_id                       7023 non-null   object
#  5   description                    1228 non-null   object
#  6   major_id                       7023 non-null   float64
#  7   is_final                       7023 non-null   bool
#  8   is_iteration                   7023 non-null   bool
#  9   is_revision                    7023 non-null   bool
#  10  is_latest_iteration            7023 non-null   bool
#  11  is_latest_revision             7023 non-null   bool
# ...

# %%
df["is_final"].value_counts().plot(kind="bar", color=["salmon", "lightblue"]);
plt.show()

# %%
df.isna().sum()
# Out:
# name                                0
# revision                            0
# db_id                               0
# object_id                           0
# group_id                            0
# description                      5795
# major_id                            0
# is_final                            0
# is_iteration                        0
# is_revision                         0
# is_latest_iteration                 0
# is_latest_revision                  0
# is_best_so_far                      0
# created_at                          0
# updated_at                          0
# finalized_at                     6808
# is_reserved                         0
# has_parent                          0
# has_child                           0
# to_relation_count                   0
# from_relation_count                 0
# has_files                           0
# file_count                          0
# is_deleted                          0
# deleted_at                       6648
# ...

# %%
df.describe()
# Out:
#              db_id    object_id     major_id  to_relation_count  \
# count  7023.000000  7023.000000  7023.000000        7023.000000
# mean   4263.389577    28.385288    28.385328           1.472021
# std    2570.221021     4.746739     4.746686           7.485696
# min       1.000000     1.819600     1.819600           0.000000
# 25%    1920.500000    27.209050    27.209100           0.000000
# 50%    4607.000000    27.565900    27.565700           0.000000
# 75%    6512.500000    27.823550    27.823700           1.000000
# max    8541.000000    74.825800    74.825800         135.000000
#
#        from_relation_count   file_count  access_rights   creator_id  \
# count          7023.000000  7023.000000            0.0  7023.000000
# mean              1.442831     0.538943            NaN    16.614695
# std               5.643430     1.341826            NaN     9.707994
# min               0.000000     0.000000            NaN     1.000000
# ...

# %%
# Are there any missing value?
df.isna().sum()
# Out:
# name                                0
# revision                            0
# db_id                               0
# object_id                           0
# group_id                            0
# description                      5795
# major_id                            0
# is_final                            0
# is_iteration                        0
# is_revision                         0
# is_latest_iteration                 0
# is_latest_revision                  0
# is_best_so_far                      0
# created_at                          0
# updated_at                          0
# finalized_at                     6808
# is_reserved                         0
# has_parent                          0
# has_child                           0
# to_relation_count                   0
# from_relation_count                 0
# has_files                           0
# file_count                          0
# is_deleted                          0
# deleted_at                       6648
# ...

# %%
df = df.dropna["description", "finalized_at","deleted_at","access_rights","deleted_at","access_rights","properties","manager_id","modifier_id","state_id","reserved_by_id","file_name","reference_id","url" ]
# Out:
# name                                0
# revision                            0
# db_id                               0
# object_id                           0
# group_id                            0
# description                      5795
# major_id                            0
# is_final                            0
# is_iteration                        0
# is_revision                         0
# is_latest_iteration                 0
# is_latest_revision                  0
# is_best_so_far                      0
# created_at                          0
# updated_at                          0
# finalized_at                     6808
# is_reserved                         0
# has_parent                          0
# has_child                           0
# to_relation_count                   0
# from_relation_count                 0
# has_files                           0
# file_count                          0
# is_deleted                          0
# deleted_at                       6648
# ...

# %%
df = df.drop(columns=["description", "finalized_at", "deleted_at", "access_rights", 
                      "properties", "manager_id", "modifier_id", "state_id", 
                      "reserved_by_id", "file_name", "reference_id", "url"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7023 entries, 0 to 7022
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           7023 non-null   object
#  1   revision                       7023 non-null   object
#  2   db_id                          7023 non-null   int64
#  3   object_id                      7023 non-null   float64
#  4   group_id                       7023 non-null   object
#  5   major_id                       7023 non-null   float64
#  6   is_final                       7023 non-null   bool
#  7   is_iteration                   7023 non-null   bool
#  8   is_revision                    7023 non-null   bool
#  9   is_latest_iteration            7023 non-null   bool
#  10  is_latest_revision             7023 non-null   bool
#  11  is_best_so_far                 7023 non-null   bool
# ...

# %%
df
# Out:
#                                                    name revision  db_id  \
# 0                                                  test        A      1
# 1                          SO.Test.10.07.2024.SubAssy.3      A.0     81
# 2                                              Node1234        A    637
# 3                                    Program - July 2nd        A     11
# 4                                  automation_item_ocoe      A.0   6193
# ...                                                 ...      ...    ...
# 7018  item_nov_18_item_item+item_nov_18_item_nov_18_...      B.0   3124
# 7019                            11_april_item00002 - 01      A.0   7995
# 7020                                 11_april_item00001      A.0   7987
# 7021                      test Docx document 12th may 1        A   8540
# 7022                      test Docx document 12th may 1      A.0   8541
#
#       object_id                          group_id  major_id  is_final  \
# ...

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Config
n_samples = 1000
priorities = ['very low', 'low', 'medium', 'high', 'very high']

# Seed for reproducibility
np.random.seed(42)

def generate_data(n):
    data = []

    for _ in range(n):
        start_date = datetime.now() - timedelta(days=np.random.randint(0, 60))
        actual_duration_days = np.random.randint(1, 15)
        actual_duration = timedelta(days=actual_duration_days)
        completion_date = start_date + actual_duration

        est_error = random.uniform(-0.2, 0.2)  # ±20% variation
        estimated_completion = start_date + timedelta(days=int(actual_duration_days * (1 + est_error)))

        task_priority = random.choice(priorities)
        remain_sub_task_level = random.choice(priorities)
        sub_task = f"{random.randint(1,5)} pending subtasks"
        total_assign_task = random.randint(1, 20)

        data.append({
            "completion_date": completion_date,
            "estimated_completion_date": estimated_completion,
            "task_priority": task_priority,
            "sub_task": sub_task,
            "remain_sub_task_level": remain_sub_task_level,
            "actual_duration": actual_duration_days,
            "start_date": start_date,
            "total_assign_task": total_assign_task
        })

    return pd.DataFrame(data)

# Generate and save
df = generate_data(n_samples)
df.to_csv("task_data.csv", index=False)
print("✅ CSV file 'task_data.csv' created successfully.")
# Out:
# ✅ CSV file 'task_data.csv' created successfully.

# %%
df
# Out:
#                completion_date  estimated_completion_date task_priority  \
# 0   2025-04-08 16:40:51.006696 2025-04-08 16:40:51.006696     very high
# 1   2025-04-25 16:40:51.008714 2025-04-26 16:40:51.008714      very low
# 2   2025-05-18 16:40:51.008714 2025-05-17 16:40:51.008714          high
# 3   2025-04-29 16:40:51.008714 2025-04-28 16:40:51.008714     very high
# 4   2025-03-19 16:40:51.008714 2025-03-18 16:40:51.008714        medium
# ..                         ...                        ...           ...
# 995 2025-04-03 16:40:51.038711 2025-04-02 16:40:51.038711          high
# 996 2025-04-12 16:40:51.038711 2025-04-12 16:40:51.038711     very high
# 997 2025-03-17 16:40:51.038711 2025-03-17 16:40:51.038711        medium
# 998 2025-03-25 16:40:51.038711 2025-03-25 16:40:51.038711        medium
# 999 2025-04-10 16:40:51.038711 2025-04-09 16:40:51.038711           low
#
#                sub_task remain_sub_task_level  actual_duration  \
# ...

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Configuration
n_samples = 1000
priorities = ['very low', 'low', 'medium', 'high', 'very high']
assignees = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Heidi']

# Seed for reproducibility
np.random.seed(42)
random.seed(42)

def generate_data(n):
    data = []

    for _ in range(n):
        assignee = random.choice(assignees)

        start_date = datetime.now() - timedelta(days=np.random.randint(0, 60))
        actual_duration_days = np.random.randint(1, 15)
        actual_duration = timedelta(days=actual_duration_days)
        completion_date = start_date + actual_duration

        est_error = random.uniform(-0.2, 0.2)  # ±20% variation
        estimated_completion = start_date + timedelta(days=int(actual_duration_days * (1 + est_error)))

        task_priority = random.choice(priorities)
        remain_sub_task_level = random.choice(priorities)
        sub_task = f"{random.randint(1,5)} pending subtasks"
        total_assign_task = random.randint(1, 20)

        data.append({
            "assignee": assignee,
            "completion_date": completion_date,
            "estimated_completion_date": estimated_completion,
            "task_priority": task_priority,
            "sub_task": sub_task,
            "remain_sub_task_level": remain_sub_task_level,
            "actual_duration": actual_duration_days,
            "start_date": start_date,
            "total_assign_task": total_assign_task
        })

    return pd.DataFrame(data)

# Generate and save
df = generate_data(n_samples)
df.to_csv("task_data.csv", index=False)
print("✅ CSV file 'task_data.csv' created successfully with assignees.")
# Out:
# ✅ CSV file 'task_data.csv' created successfully with assignees.

# %%
df
# Out:
#     assignee            completion_date  estimated_completion_date  \
# 0        Bob 2025-04-08 16:45:00.893243 2025-04-07 16:45:00.893243
# 1        Bob 2025-04-25 16:45:00.893243 2025-04-25 16:45:00.893243
# 2      Alice 2025-05-18 16:45:00.893243 2025-05-15 16:45:00.893243
# 3      Alice 2025-04-29 16:45:00.893243 2025-04-29 16:45:00.893243
# 4        Eve 2025-03-19 16:45:00.893243 2025-03-19 16:45:00.893243
# ..       ...                        ...                        ...
# 995      Bob 2025-04-03 16:45:00.921213 2025-04-03 16:45:00.921213
# 996    Alice 2025-04-12 16:45:00.921213 2025-04-11 16:45:00.921213
# 997  Charlie 2025-03-17 16:45:00.921213 2025-03-16 16:45:00.921213
# 998    Heidi 2025-03-25 16:45:00.921213 2025-03-23 16:45:00.921213
# 999    Grace 2025-04-10 16:45:00.921213 2025-04-10 16:45:00.921213
#
#     task_priority            sub_task remain_sub_task_level  actual_duration  \
# 0          medium  2 pending subtasks                   low                4
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error
import datetime

# %%
df = pd.read_csv("task_data.csv")

# %%
df
# Out:
#     assignee             completion_date   estimated_completion_date  \
# 0        Bob  2025-04-08 16:45:13.438214  2025-04-07 16:45:13.438214
# 1        Bob  2025-04-25 16:45:13.439210  2025-04-25 16:45:13.439210
# 2      Alice  2025-05-18 16:45:13.439210  2025-05-15 16:45:13.439210
# 3      Alice  2025-04-29 16:45:13.439210  2025-04-29 16:45:13.439210
# 4        Eve  2025-03-19 16:45:13.439210  2025-03-19 16:45:13.439210
# ..       ...                         ...                         ...
# 995      Bob  2025-04-03 16:45:13.469219  2025-04-03 16:45:13.469219
# 996    Alice  2025-04-12 16:45:13.469219  2025-04-11 16:45:13.469219
# 997  Charlie  2025-03-17 16:45:13.469219  2025-03-16 16:45:13.469219
# 998    Heidi  2025-03-25 16:45:13.469219  2025-03-23 16:45:13.469219
# 999    Grace  2025-04-10 16:45:13.469219  2025-04-10 16:45:13.469219
#
#     task_priority            sub_task remain_sub_task_level  actual_duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   assignee                   1000 non-null   object
#  1   completion_date            1000 non-null   object
#  2   estimated_completion_date  1000 non-null   object
#  3   task_priority              1000 non-null   object
#  4   sub_task                   1000 non-null   object
#  5   remain_sub_task_level      1000 non-null   object
#  6   actual_duration            1000 non-null   int64
#  7   start_date                 1000 non-null   object
#  8   total_assign_task          1000 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 70.4+ KB

# %%
le_assignee = LabelEncoder()
le_priority = LabelEncoder()
le_remain_priority = LabelEncoder()

# %%
df["assignee_enc"] = le_assignee.fit_transform(df["assignee"])
df["task_priority_enc"] = le_priority.fit_transform(df["task_priority"])
df["remain_priority_enc"] = le_remain_priority.fit_transform(df["remain_sub_task_level"])

# %%
df["assignee_enc"].value_counts()
# Out:
# assignee_enc
# 1    133
# 2    131
# 7    129
# 0    127
# 4    123
# 5    123
# 6    122
# 3    112
# Name: count, dtype: int64

# %%
df["task_priority_enc"].value_counts()
# Out:
# task_priority_enc
# 3    217
# 1    207
# 0    205
# 2    188
# 4    183
# Name: count, dtype: int64

# %%
# Out:
#     assignee             completion_date   estimated_completion_date  \
# 0        Bob  2025-04-08 16:45:13.438214  2025-04-07 16:45:13.438214
# 1        Bob  2025-04-25 16:45:13.439210  2025-04-25 16:45:13.439210
# 2      Alice  2025-05-18 16:45:13.439210  2025-05-15 16:45:13.439210
# 3      Alice  2025-04-29 16:45:13.439210  2025-04-29 16:45:13.439210
# 4        Eve  2025-03-19 16:45:13.439210  2025-03-19 16:45:13.439210
# ..       ...                         ...                         ...
# 995      Bob  2025-04-03 16:45:13.469219  2025-04-03 16:45:13.469219
# 996    Alice  2025-04-12 16:45:13.469219  2025-04-11 16:45:13.469219
# 997  Charlie  2025-03-17 16:45:13.469219  2025-03-16 16:45:13.469219
# 998    Heidi  2025-03-25 16:45:13.469219  2025-03-23 16:45:13.469219
# 999    Grace  2025-04-10 16:45:13.469219  2025-04-10 16:45:13.469219
#
#     task_priority            sub_task remain_sub_task_level  actual_duration  \
# ...
